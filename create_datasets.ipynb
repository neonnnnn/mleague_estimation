# %%
import requests
from bs4 import BeautifulSoup
import json
import os
import datetime
import re

# %%
url_base = 'https://m-league.jp/'
years = [2018, 2019, 2020]

# %%
def parse_match(match):
    match_parsed = {}
    for result_per_player in match.find_all('div', {'class': 'p-gamesResult__name-wrap'}):
        name = result_per_player.find('div', {'class': 'p-gamesResult__name'}).get_text()
        score = result_per_player.find('div', {'class': 'p-gamesResult__point'}).get_text(strip=True)
        match_parsed[name] = float(score.replace('▲', '-').strip('pt'))
    return match_parsed

# %%
save_dir = os.path.join('data')
os.makedirs(save_dir, exist_ok=True)
for year in years:
    print(year)
    if year == 2020:
        url = f"{url_base}/games"
    else:
        url = f"{url_base}/{year}-season/"
        
    res = requests.get(url)
    soup = BeautifulSoup(res.text, 'html.parser')
    results_all = soup.find_all('div', {'class': 'p-gamesResult'})
    for results in results_all:
        try:
            date = results.find('div', {'class': 'p-gamesResult__date'}).get_text()
            date = re.sub(r'\(.\)', '', date)
            date = datetime.datetime.strptime(f"{year}/{date}", '%Y/%m/%d')
            fname = f'{date.strftime("%Y%m%d")}' 
            for i, match in enumerate(results.find_all('div', {'class': 'p-gamesResult__column'})):
                match_parsed = parse_match(match) 
                print(fname, i, match_parsed)
                with open(os.path.join(save_dir, f"{fname}_{i}.json"), 'w') as f:
                    json.dump(match_parsed, f, ensure_ascii=False, indent=2)
        except ValueError:
            print("Read template.")
# Out:
# 2018
# Read template.
# 20180302 0 {'鈴木たろう': 65.3, '高宮まり': 15.1, '二階堂亜樹': -20.6, '多井隆晴': -59.8}
# 20180302 1 {'村上淳': 62.4, '勝又健志': 14.2, '白鳥翔': -22.2, '佐々木寿人': -54.4}
# 20180302 2 {'鈴木たろう': 55.4, '佐々木寿人': 6.9, '松本吉弘': -19.8, '滝沢和典': -42.5}
# 20180303 0 {'二階堂亜樹': 73.2, '前原雄大': 8.8, '村上淳': -28.7, '松本吉弘': -53.3}
# 20180303 1 {'白鳥翔': 55.8, '鈴木たろう': 15.6, '高宮まり': -20.4, '二階堂亜樹': -51.0}
# 20180303 2 {'勝又健志': 62.1, '園田賢': 13.6, '佐々木寿人': -16.5, '白鳥翔': -59.2}
# 20180309 0 {'滝沢和典': 66.3, '鈴木たろう': 21.8, '白鳥翔': -18.2, '前原雄大': -69.9}
# 20180309 1 {'松本吉弘': 64.9, '佐々木寿人': 10.8, '滝沢和典': -19.0, '村上淳': -56.7}
# 20180309 2 {'鈴木たろう': 64.1, '高宮まり': 6.7, '多井隆晴': -22.3, '勝又健志': -48.5}
# 20180310 0 {'二階堂亜樹': 62.2, '前原雄大': 18.8, '園田賢': -25.6, '多井隆晴': -55.4}
# 20180310 1 {'鈴木たろう': 52.3, '佐々木寿人': 8.7, '勝又健志': -15.6, '松本吉弘': -45.4}
# 20180310 2 {'園田賢': 54.8, '高宮まり': 11.1, '滝沢和典': -15.9, '白鳥翔': -50.0}
# 20180323 0 {'村上淳': 99.9, '佐々木寿人': -5.9, '二階堂亜樹': -27.5, '多井隆晴': -66.5}
# 20180323 1 {'園田賢': 75.4, '滝沢和典': 26.5, '松本吉弘': -34.7, '佐々木寿人': -67.2}
# 20180323 2 {'勝又健志': 60.3, '多井隆晴': 3.2, '鈴木たろう': -21.3, '前原雄大': -42.2}
# 20180324 0 {'白鳥翔': 68.9, '園田賢': 5.4, '勝又健志': -26.2, '高宮まり': -48.1}
# 20180324 1 {'多井隆晴': 59.2, '村上淳': 18.7, '前原雄大': -23.3, '滝沢和典': -54.6}
# 20180324 2 {'佐々木寿人': 63.8, '二階堂亜樹': 7.5, '鈴木たろう': -17.9, '多井隆晴': -53.4}
# 20180330 0 {'鈴木たろう': 76.8, '勝又健志': -3.8, '松本吉弘': -24.8, '前原雄大': -48.2}
# 20180330 1 {'村上淳': 61.7, '勝又健志': 15.2, '佐々木寿人': -24.7, '白鳥翔': -52.2}
# 20180330 2 {'滝沢和典': 61.9, '多井隆晴': 5.8, '園田賢': -23.6, '佐々木寿人': -44.1}
# 20180331 0 {'高宮まり': 72.7, '村上淳': 4.8, '松本吉弘': -22.2, '二階堂亜樹': -55.3}
# 20180331 1 {'白鳥翔': 88.2, '園田賢': -2.5, '前原雄大': -28.6, '滝沢和典': -57.1}
# 20180331 2 {'多井隆晴': 74.1, '鈴木たろう': 27.1, '佐々木寿人': -31.5, '勝又健志': -69.7}
# 20181001 0 {'園田賢': 62.9, '小林剛': 18.4, '萩原聖人': -23.3, '魚谷侑未': -58.0}
# 20181001 1 {'石橋伸洋': 63.5, '鈴木たろう': 6.3, '茅森早香': -21.5, '萩原聖人': -48.3}
# 20181002 0 {'村上淳': 50.8, '佐々木寿人': 7.6, '松本吉弘': -13.4, '滝沢和典': -45.0}
# 20181002 1 {'多井隆晴': 75.4, '勝又健志': 4.1, '佐々木寿人': -21.6, '園田賢': -57.9}
# 20181004 0 {'白鳥翔': 64.7, '朝倉康心': 15.2, '二階堂亜樹': -29.0, '前原雄大': -50.9}
# 20181004 1 {'松本吉弘': 80.9, '二階堂亜樹': 10.0, '小林剛': -17.4, '佐々木寿人': -73.5}
# 20181005 0 {'村上淳': 65.0, '高宮まり': 14.7, '黒沢咲': -14.0, '石橋伸洋': -65.7}
# 20181005 1 {'鈴木たろう': 79.7, '朝倉康心': 9.9, '高宮まり': -25.5, '瀬戸熊直樹': -64.1}
# 20181008 0 {'瀬戸熊直樹': 60.9, '白鳥翔': 17.6, '小林剛': -25.9, '佐々木寿人': -52.6}
# 20181008 1 {'前原雄大': 56.9, '小林剛': 14.7, '松本吉弘': -23.8, '萩原聖人': -47.8}
# 20181009 0 {'白鳥翔': 71.0, '前原雄大': -1.5, '石橋伸洋': -21.6, '茅森早香': -47.9}
# 20181009 1 {'多井隆晴': 68.1, '朝倉康心': 18.0, '茅森早香': -15.3, '佐々木寿人': -70.8}
# 20181011 0 {'近藤誠一': 75.5, '村上淳': 5.9, '勝又健志': -28.6, '黒沢咲': -52.8}
# 20181011 1 {'近藤誠一': 61.1, '萩原聖人': 12.1, '二階堂亜樹': -10.5, '鈴木たろう': -62.7}
# 20181012 0 {'滝沢和典': 55.8, '朝倉康心': 11.8, '白鳥翔': -18.7, '前原雄大': -48.9}
# 20181012 1 {'松本吉弘': 92.8, '小林剛': 18.6, '滝沢和典': -21.9, '前原雄大': -89.5}
# 20181015 0 {'前原雄大': 90.6, '松本吉弘': -1.9, '小林剛': -33.6, '村上淳': -55.1}
# 20181015 1 {'園田賢': 69.6, '前原雄大': 7.0, '石橋伸洋': -25.5, '白鳥翔': -51.1}
# 20181016 0 {'滝沢和典': 74.1, '多井隆晴': 10.2, '瀬戸熊直樹': -15.8, '鈴木たろう': -68.5}
# 20181016 1 {'瀬戸熊直樹': 69.1, '園田賢': 13.2, '二階堂亜樹': -12.5, '白鳥翔': -69.8}
# 20181018 0 {'萩原聖人': 62.0, '近藤誠一': 3.4, '高宮まり': -21.6, '朝倉康心': -43.8}
# 20181018 1 {'魚谷侑未': 56.0, '小林剛': 9.6, '佐々木寿人': -14.9, '萩原聖人': -50.7}
# 20181019 0 {'多井隆晴': 55.7, '村上淳': 7.0, '二階堂亜樹': -20.3, '魚谷侑未': -42.4}
# 20181019 1 {'二階堂亜樹': 59.9, '園田賢': 9.5, '松本吉弘': -23.7, '近藤誠一': -45.7}
# 20181022 0 {'黒沢咲': 67.2, '二階堂亜樹': 8.1, '魚谷侑未': -22.2, '高宮まり': -53.1}
# 20181022 1 {'瀬戸熊直樹': 62.5, '魚谷侑未': 7.5, '滝沢和典': -23.7, '佐々木寿人': -46.3}
# 20181023 0 {'近藤誠一': 54.0, '石橋伸洋': 13.2, '勝又健志': -15.2, '瀬戸熊直樹': -52.0}
# 20181023 1 {'朝倉康心': 52.8, '勝又健志': 11.2, '茅森早香': -21.9, '萩原聖人': -42.1}
# 20181025 0 {'小林剛': 68.0, '滝沢和典': 18.2, '白鳥翔': -31.3, '鈴木たろう': -54.9}
# 20181025 1 {'朝倉康心': 76.3, '多井隆晴': 10.8, '勝又健志': -27.4, '村上淳': -59.7}
# 20181026 0 {'佐々木寿人': 86.4, '魚谷侑未': 20.1, '村上淳': -36.9, '松本吉弘': -69.6}
# 20181026 1 {'佐々木寿人': 61.9, '園田賢': -5.2, '魚谷侑未': -5.2, '白鳥翔': -51.5}
# 20181029 0 {'村上淳': 50.3, '近藤誠一': 8.3, '石橋伸洋': -16.0, '佐々木寿人': -42.6}
# 20181029 1 {'佐々木寿人': 72.8, '小林剛': 16.0, '近藤誠一': -28.1, '園田賢': -60.7}
# 20181030 0 {'茅森早香': 76.4, '黒沢咲': 15.9, '多井隆晴': -17.7, '前原雄大': -74.6}
# 20181030 1 {'多井隆晴': 72.0, '高宮まり': 6.7, '萩原聖人': -18.5, '茅森早香': -60.2}
# 20181101 0 {'二階堂亜樹': 63.5, '前原雄大': 16.0, '萩原聖人': -13.8, '白鳥翔': -65.7}
# 20181101 1 {'瀬戸熊直樹': 61.2, '松本吉弘': 7.6, '勝又健志': -18.2, '前原雄大': -50.6}
# 20181102 0 {'二階堂亜樹': 53.1, '村上淳': 10.9, '石橋伸洋': -21.4, '近藤誠一': -42.6}
# 20181102 1 {'園田賢': 52.7, '近藤誠一': 8.1, '勝又健志': -12.1, '朝倉康心': -48.7}
# 20181105 0 {'二階堂亜樹': 58.1, '石橋伸洋': 15.1, '黒沢咲': -14.1, '村上淳': -59.1}
# 20181105 1 {'滝沢和典': 52.3, '園田賢': 8.5, '朝倉康心': -12.5, '瀬戸熊直樹': -48.3}
# 20181106 0 {'白鳥翔': 55.7, '魚谷侑未': 9.0, '小林剛': -18.4, '鈴木たろう': -46.3}
# 20181106 1 {'小林剛': 58.2, '鈴木たろう': 5.0, '白鳥翔': -17.8, '魚谷侑未': -45.4}
# 20181108 0 {'茅森早香': 56.6, '村上淳': 11.3, '瀬戸熊直樹': -21.0, '高宮まり': -46.9}
# 20181108 1 {'高宮まり': 48.7, '茅森早香': 6.9, '鈴木たろう': -16.3, '萩原聖人': -39.3}
# 20181109 0 {'前原雄大': 70.6, '勝又健志': 13.6, '多井隆晴': -20.8, '近藤誠一': -63.4}
# 20181109 1 {'松本吉弘': 52.0, '前原雄大': 8.0, '二階堂亜樹': -15.7, '魚谷侑未': -44.3}
# 20181112 0 {'佐々木寿人': 53.7, '朝倉康心': 9.0, '二階堂亜樹': -15.9, '黒沢咲': -46.8}
# 20181112 1 {'石橋伸洋': 54.5, '佐々木寿人': 10.4, '滝沢和典': -17.4, '萩原聖人': -47.5}
# 20181113 0 {'茅森早香': 69.4, '萩原聖人': 5.6, '白鳥翔': -17.2, '鈴木たろう': -57.8}
# 20181113 1 {'園田賢': 54.7, '黒沢咲': 12.9, '茅森早香': -22.1, '松本吉弘': -45.5}
# 20181115 0 {'鈴木たろう': 67.0, '瀬戸熊直樹': 14.2, '白鳥翔': -21.4, '石橋伸洋': -59.8}
# 20181115 1 {'鈴木たろう': 69.5, '瀬戸熊直樹': 19.5, '小林剛': -29.5, '多井隆晴': -59.5}
# 20181116 0 {'茅森早香': 58.7, '滝沢和典': 10.7, '高宮まり': -23.2, '朝倉康心': -46.2}
# 20181116 1 {'勝又健志': 77.9, '小林剛': -5.3, '魚谷侑未': -26.0, '高宮まり': -46.6}
# 20181119 0 {'鈴木たろう': 64.9, '朝倉康心': 0.7, '二階堂亜樹': -20.3, '佐々木寿人': -45.3}
# 20181119 1 {'佐々木寿人': 63.0, '鈴木たろう': 18.1, '滝沢和典': -22.0, '石橋伸洋': -59.1}
# 20181120 0 {'黒沢咲': 59.1, '松本吉弘': 5.3, '小林剛': -19.2, '勝又健志': -45.2}
# 20181120 1 {'勝又健志': 75.6, '瀬戸熊直樹': -2.2, '白鳥翔': -26.2, '小林剛': -47.2}
# 20181122 0 {'茅森早香': 54.4, '前原雄大': 12.6, '滝沢和典': -15.3, '鈴木たろう': -51.7}
# 20181122 1 {'鈴木たろう': 55.6, '佐々木寿人': 7.7, '茅森早香': -20.2, '滝沢和典': -43.1}
# 20181123 0 {'魚谷侑未': 54.8, '黒沢咲': 14.2, '多井隆晴': -13.9, '小林剛': -55.1}
# 20181123 1 {'石橋伸洋': 65.3, '萩原聖人': 15.3, '魚谷侑未': -20.9, '多井隆晴': -59.7}
# 20181126 0 {'白鳥翔': 52.7, '村上淳': 8.3, '黒沢咲': -18.5, '佐々木寿人': -42.5}
# 20181126 1 {'瀬戸熊直樹': 58.5, '園田賢': 3.7, '白鳥翔': -20.1, '佐々木寿人': -42.1}
# 20181127 0 {'黒沢咲': 71.9, '二階堂亜樹': 1.3, '高宮まり': -20.0, '鈴木たろう': -53.2}
# 20181127 1 {'鈴木たろう': 67.5, '高宮まり': 8.8, '萩原聖人': -27.1, '勝又健志': -49.2}
# 20181129 0 {'松本吉弘': 74.0, '石橋伸洋': 3.0, '滝沢和典': -22.6, '茅森早香': -54.4}
# 20181129 1 {'滝沢和典': 69.5, '石橋伸洋': 10.6, '魚谷侑未': -28.4, '松本吉弘': -51.7}
# 20181130 0 {'黒沢咲': 52.5, '勝又健志': 8.2, '佐々木寿人': -17.1, '村上淳': -43.6}
# 20181130 1 {'園田賢': 52.1, '瀬戸熊直樹': 11.8, '佐々木寿人': -20.3, '二階堂亜樹': -43.6}
# 20181203 0 {'朝倉康心': 54.0, '鈴木たろう': 4.4, '茅森早香': -18.8, '萩原聖人': -39.6}
# 20181203 1 {'園田賢': 64.0, '黒沢咲': 7.7, '朝倉康心': -21.9, '魚谷侑未': -49.8}
# 20181204 0 {'近藤誠一': 57.4, '勝又健志': 11.5, '白鳥翔': -14.0, '瀬戸熊直樹': -54.9}
# 20181204 1 {'勝又健志': 56.8, '近藤誠一': 9.9, '瀬戸熊直樹': -15.1, '松本吉弘': -51.6}
# 20181206 0 {'滝沢和典': 68.1, '村上淳': 1.2, '佐々木寿人': -19.1, '白鳥翔': -50.2}
# 20181206 1 {'佐々木寿人': 63.9, '滝沢和典': 6.2, '多井隆晴': -15.0, '園田賢': -55.1}
# 20181207 0 {'黒沢咲': 79.2, '鈴木たろう': 3.5, '前原雄大': -29.5, '朝倉康心': -53.2}
# 20181207 1 {'萩原聖人': 67.2, '高宮まり': 23.9, '石橋伸洋': -26.0, '村上淳': -65.1}
# 20181210 0 {'佐々木寿人': 61.6, '黒沢咲': 12.1, '石橋伸洋': -23.8, '松本吉弘': -49.9}
# 20181210 1 {'佐々木寿人': 52.4, '多井隆晴': 10.9, '朝倉康心': -20.0, '瀬戸熊直樹': -43.3}
# 20181211 0 {'松本吉弘': 66.9, '小林剛': 22.6, '魚谷侑未': -22.6, '高宮まり': -66.9}
# 20181211 1 {'石橋伸洋': 67.1, '魚谷侑未': 13.5, '前原雄大': -23.0, '松本吉弘': -57.6}
# 20181213 0 {'魚谷侑未': 73.0, '勝又健志': 2.7, '黒沢咲': -27.7, '鈴木たろう': -48.0}
# 20181213 1 {'園田賢': 61.9, '萩原聖人': 10.3, '滝沢和典': -16.9, '茅森早香': -55.3}
# 20181214 0 {'白鳥翔': 51.2, '黒沢咲': 4.6, '滝沢和典': -16.6, '茅森早香': -39.2}
# 20181214 1 {'萩原聖人': 51.5, '勝又健志': 6.2, '茅森早香': -16.8, '白鳥翔': -40.9}
# 20181217 0 {'朝倉康心': 56.0, '前原雄大': 13.9, '多井隆晴': -23.1, '村上淳': -46.8}
# 20181217 1 {'前原雄大': 78.9, '松本吉弘': 7.5, '園田賢': -22.2, '石橋伸洋': -64.2}
# 20181218 0 {'鈴木たろう': 81.0, '松本吉弘': 11.9, '二階堂亜樹': -29.2, '瀬戸熊直樹': -63.7}
# 20181218 1 {'白鳥翔': 78.5, '園田賢': 32.4, '滝沢和典': -29.5, '瀬戸熊直樹': -81.4}
# 20181220 0 {'萩原聖人': 56.1, '茅森早香': 5.3, '前原雄大': -18.6, '小林剛': -42.8}
# 20181220 1 {'前原雄大': 59.1, '瀬戸熊直樹': 5.2, '石橋伸洋': -21.6, '近藤誠一': -42.7}
# 20181221 0 {'鈴木たろう': 65.2, '茅森早香': 15.3, '勝又健志': -20.6, '多井隆晴': -59.9}
# 20181221 1 {'園田賢': 60.0, '滝沢和典': 10.0, '松本吉弘': -22.7, '近藤誠一': -47.3}
# 20180107 0 {'佐々木寿人': 101.7, '二階堂亜樹': -8.9, '茅森早香': -30.3, '黒沢咲': -62.5}
# 20180107 1 {'勝又健志': 77.0, '佐々木寿人': 14.0, '萩原聖人': -34.7, '近藤誠一': -56.3}
# 20180108 0 {'萩原聖人': 65.6, '滝沢和典': 7.8, '朝倉康心': -16.9, '魚谷侑未': -56.5}
# 20180108 1 {'勝又健志': 54.6, '魚谷侑未': 3.7, '瀬戸熊直樹': -19.1, '小林剛': -39.2}
# 20180110 0 {'村上淳': 68.5, '朝倉康心': 11.7, '二階堂亜樹': -16.2, '多井隆晴': -64.0}
# 20180110 1 {'滝沢和典': 95.2, '小林剛': -5.2, '鈴木たろう': -33.0, '白鳥翔': -57.0}
# 20180111 0 {'松本吉弘': 70.7, '魚谷侑未': 8.1, '佐々木寿人': -20.4, '鈴木たろう': -58.4}
# 20180111 1 {'多井隆晴': 62.0, '茅森早香': 20.2, '園田賢': -22.8, '佐々木寿人': -59.4}
# 20180114 0 {'前原雄大': 67.3, '石橋伸洋': 5.1, '魚谷侑未': -22.4, '園田賢': -50.0}
# 20180114 1 {'魚谷侑未': 57.1, '園田賢': 12.7, '小林剛': -15.4, '前原雄大': -54.4}
# 20180115 0 {'滝沢和典': 65.3, '朝倉康心': 3.8, '近藤誠一': -20.2, '園田賢': -48.9}
# 20180115 1 {'園田賢': 64.6, '石橋伸洋': 14.7, '近藤誠一': -10.9, '二階堂亜樹': -68.4}
# 20180117 0 {'松本吉弘': 60.7, '萩原聖人': 13.9, '滝沢和典': -19.7, '高宮まり': -54.9}
# 20180117 1 {'瀬戸熊直樹': 75.0, '高宮まり': 31.3, '勝又健志': -31.9, '白鳥翔': -74.4}
# 20180118 0 {'佐々木寿人': 72.1, '萩原聖人': 15.3, '茅森早香': -20.9, '白鳥翔': -66.5}
# 20180118 1 {'茅森早香': 55.3, '佐々木寿人': 10.5, '松本吉弘': -22.1, '瀬戸熊直樹': -43.7}
# 20180121 0 {'小林剛': 53.3, '二階堂亜樹': 11.3, '村上淳': -17.5, '黒沢咲': -47.1}
# 20180121 1 {'鈴木たろう': 52.4, '朝倉康心': 5.5, '萩原聖人': -16.8, '滝沢和典': -41.1}
# 20180122 0 {'多井隆晴': 73.9, '石橋伸洋': 21.4, '村上淳': -37.3, '魚谷侑未': -58.0}
# 20180122 1 {'魚谷侑未': 62.0, '多井隆晴': 5.6, '小林剛': -20.6, '園田賢': -47.0}
# 20180124 0 {'近藤誠一': 61.0, '前原雄大': 9.2, '萩原聖人': -13.5, '鈴木たろう': -56.7}
# 20180124 1 {'近藤誠一': 60.4, '前原雄大': 9.5, '園田賢': -22.5, '瀬戸熊直樹': -47.4}
# 20180125 0 {'多井隆晴': 53.8, '二階堂亜樹': 6.7, '茅森早香': -17.7, '佐々木寿人': -42.8}
# 20180125 1 {'茅森早香': 63.7, '佐々木寿人': 8.6, '勝又健志': -23.3, '松本吉弘': -49.0}
# 20180128 0 {'朝倉康心': 58.9, '二階堂亜樹': 8.2, '前原雄大': -12.0, '萩原聖人': -55.1}
# 20180128 1 {'黒沢咲': 61.5, '二階堂亜樹': 7.6, '前原雄大': -13.6, '朝倉康心': -55.5}
# 20180129 0 {'小林剛': 65.2, '佐々木寿人': 25.1, '滝沢和典': -21.1, '魚谷侑未': -69.2}
# 20180129 1 {'滝沢和典': 55.7, '佐々木寿人': 5.9, '石橋伸洋': -19.0, '魚谷侑未': -42.6}
# 20180131 0 {'朝倉康心': 64.8, '多井隆晴': 22.0, '村上淳': -20.1, '黒沢咲': -66.7}
# 20180131 1 {'鈴木たろう': 67.2, '多井隆晴': 14.1, '小林剛': -8.2, '瀬戸熊直樹': -73.1}
# 20180201 0 {'近藤誠一': 70.1, '白鳥翔': 10.4, '鈴木たろう': -19.0, '瀬戸熊直樹': -61.5}
# 20180201 1 {'萩原聖人': 83.2, '近藤誠一': 14.7, '松本吉弘': -38.8, '園田賢': -59.1}
# 20180204 0 {'園田賢': 62.7, '朝倉康心': -8.2, '前原雄大': -8.2, '二階堂亜樹': -46.3}
# 20180204 1 {'園田賢': 52.3, '佐々木寿人': 11.8, '石橋伸洋': -19.3, '勝又健志': -44.8}
# 20180205 0 {'多井隆晴': 62.3, '朝倉康心': 21.0, '滝沢和典': -26.3, '萩原聖人': -57.0}
# 20180205 1 {'多井隆晴': 75.2, '黒沢咲': 8.3, '勝又健志': -22.0, '小林剛': -61.5}
# 20180207 0 {'佐々木寿人': 53.0, '勝又健志': 10.6, '茅森早香': -12.9, '鈴木たろう': -50.7}
# 20180207 1 {'滝沢和典': 99.6, '佐々木寿人': 15.5, '茅森早香': -29.8, '園田賢': -85.3}
# 20180208 0 {'多井隆晴': 63.0, '瀬戸熊直樹': 1.6, '朝倉康心': -19.4, '近藤誠一': -45.2}
# 20180208 1 {'多井隆晴': 59.9, '近藤誠一': 6.6, '萩原聖人': -13.6, '石橋伸洋': -52.9}
# 20180211 0 {'前原雄大': 60.5, '松本吉弘': 10.7, '瀬戸熊直樹': -16.3, '園田賢': -54.9}
# 20180211 1 {'萩原聖人': 69.6, '松本吉弘': 2.4, '園田賢': -22.7, '高宮まり': -49.3}
# 20180212 0 {'朝倉康心': 55.7, '滝沢和典': 8.5, '白鳥翔': -21.8, '茅森早香': -42.4}
# 20180212 1 {'近藤誠一': 56.3, '多井隆晴': 15.0, '小林剛': -15.7, '勝又健志': -55.6}
# 2019
# 20190930 0 {'魚谷侑未': 72.3, '萩原聖人': 13.8, '小林剛': -17.1, '白鳥翔': -69.0}
# 20190930 1 {'黒沢咲': 61.3, '茅森早香': 7.6, '多井隆晴': -20.6, '朝倉康心': -48.3}
# 20191001 0 {'高宮まり': 66.9, '滝沢和典': 19.1, '内川幸太郎': -24.6, '鈴木たろう': -61.4}
# 20191001 1 {'勝又健志': 73.9, '前原雄大': 3.5, '岡田紗佳': -20.2, '園田賢': -57.2}
# 20191003 0 {'瑞原明奈': 61.9, '沢崎誠': 9.6, '佐々木寿人': -22.0, '瀬戸熊直樹': -49.5}
# 20191003 1 {'沢崎誠': 57.6, '石橋伸洋': 5.8, '萩原聖人': -16.2, '佐々木寿人': -47.2}
# 20191004 0 {'近藤誠一': 53.2, '二階堂亜樹': 11.4, '鈴木たろう': -20.6, '松本吉弘': -44.0}
# 20191004 1 {'村上淳': 57.6, '日向藍子': 4.6, '魚谷侑未': -19.9, '勝又健志': -42.3}
# 20191007 0 {'瑞原明奈': 70.5, '岡田紗佳': 6.6, '前原雄大': -18.7, '二階堂亜樹': -58.4}
# 20191007 1 {'滝沢和典': 60.7, '岡田紗佳': 17.0, '高宮まり': -11.4, '朝倉康心': -66.3}
# 20191008 0 {'多井隆晴': 72.9, '萩原聖人': 10.9, '村上淳': -13.2, '和久津晶': -70.6}
# 20191008 1 {'茅森早香': 57.3, '日向藍子': 2.8, '園田賢': -18.7, '瀬戸熊直樹': -41.4}
# 20191010 0 {'勝又健志': 73.0, '松本吉弘': 22.3, '鈴木たろう': -23.7, '瑞原明奈': -71.6}
# 20191010 1 {'白鳥翔': 59.8, '園田賢': 11.4, '小林剛': -22.8, '滝沢和典': -48.4}
# 20191011 0 {'近藤誠一': 76.2, '瀬戸熊直樹': 7.4, '藤崎智': -28.7, '内川幸太郎': -54.9}
# 20191011 1 {'沢崎誠': 59.1, '黒沢咲': 8.6, '茅森早香': -17.5, '高宮まり': -50.2}
# 20191014 0 {'岡田紗佳': 63.7, '二階堂亜樹': 4.5, '園田賢': -20.3, '黒沢咲': -47.9}
# 20191014 1 {'二階堂亜樹': 58.8, '沢崎誠': 5.6, '萩原聖人': -20.3, '村上淳': -44.1}
# 20191015 0 {'高宮まり': 58.4, '石橋伸洋': 7.9, '茅森早香': -21.2, '松本吉弘': -45.1}
# 20191015 1 {'白鳥翔': 71.6, '藤崎智': 3.2, '小林剛': -24.4, '和久津晶': -50.4}
# 20191017 0 {'黒沢咲': 57.4, '小林剛': 16.9, '佐々木寿人': -25.3, '鈴木たろう': -49.0}
# 20191017 1 {'萩原聖人': 54.1, '園田賢': 12.0, '高宮まり': -8.4, '瑞原明奈': -57.7}
# 20191018 0 {'日向藍子': 63.7, '沢崎誠': 9.3, '滝沢和典': -17.1, '魚谷侑未': -55.9}
# 20191018 1 {'多井隆晴': 79.9, '滝沢和典': 12.2, '近藤誠一': -33.3, '内川幸太郎': -58.8}
# 20191021 0 {'小林剛': 84.1, '村上淳': 13.7, '黒沢咲': -24.0, '松本吉弘': -73.8}
# 20191021 1 {'鈴木たろう': 54.1, '白鳥翔': 5.7, '朝倉康心': -29.9, '瀬戸熊直樹': -29.9}
# 20191022 0 {'前原雄大': 55.7, '近藤誠一': 13.2, '岡田紗佳': -17.4, '勝又健志': -51.5}
# 20191022 1 {'内川幸太郎': 57.1, '滝沢和典': 13.5, '藤崎智': -23.8, '和久津晶': -46.8}
# 20191024 0 {'魚谷侑未': 76.3, '瀬戸熊直樹': 25.5, '藤崎智': -29.6, '日向藍子': -72.2}
# 20191024 1 {'魚谷侑未': 51.7, '萩原聖人': 10.1, '多井隆晴': -14.0, '佐々木寿人': -47.8}
# 20191025 0 {'沢崎誠': 64.2, '滝沢和典': 13.0, '瑞原明奈': -17.2, '村上淳': -60.0}
# 20191025 1 {'石橋伸洋': 73.4, '沢崎誠': 6.4, '園田賢': -23.0, '勝又健志': -56.8}
# 20191026 0 {'園田賢': 55.0, '茅森早香': 10.1, '二階堂亜樹': -20.5, '黒沢咲': -44.6}
# 20191026 1 {'瀬戸熊直樹': 75.2, '勝又健志': 31.8, '鈴木たろう': -34.5, '茅森早香': -72.5}
# 20191028 0 {'白鳥翔': 61.8, '石橋伸洋': 11.0, '佐々木寿人': -20.0, '岡田紗佳': -52.8}
# 20191028 1 {'小林剛': 49.2, '内川幸太郎': 9.0, '藤崎智': -18.4, '松本吉弘': -39.8}
# 20191029 0 {'丸山奏子': 52.7, '滝沢和典': 7.1, '多井隆晴': -13.3, '佐々木寿人': -46.5}
# 20191029 1 {'前原雄大': 66.6, '園田賢': 19.8, '日向藍子': -32.5, '二階堂亜樹': -53.9}
# 20191031 0 {'瀬戸熊直樹': 50.0, '茅森早香': 8.6, '瑞原明奈': -15.7, '沢崎誠': -42.9}
# 20191031 1 {'小林剛': 33.9, '岡田紗佳': 33.9, '黒沢咲': -19.0, '魚谷侑未': -48.8}
# 20191101 0 {'松本吉弘': 56.0, '高宮まり': 7.3, '朝倉康心': -16.1, '鈴木たろう': -47.2}
# 20191101 1 {'瑞原明奈': 64.1, '園田賢': 17.5, '高宮まり': -25.9, '多井隆晴': -55.7}
# 20191104 0 {'勝又健志': 66.9, '茅森早香': 18.6, '沢崎誠': -27.0, '萩原聖人': -58.5}
# 20191104 1 {'魚谷侑未': 66.6, '沢崎誠': 10.7, '黒沢咲': -17.7, '勝又健志': -59.6}
# 20191105 0 {'前原雄大': 63.8, '和久津晶': 3.0, '内川幸太郎': -21.4, '白鳥翔': -45.4}
# 20191105 1 {'内川幸太郎': 51.0, '多井隆晴': 5.5, '藤崎智': -16.0, '魚谷侑未': -40.5}
# 20191107 0 {'瀬戸熊直樹': 72.0, '滝沢和典': 29.0, '村上淳': -37.4, '石橋伸洋': -63.6}
# 20191107 1 {'滝沢和典': 52.5, '萩原聖人': 5.1, '小林剛': -16.1, '園田賢': -41.5}
# 20191108 0 {'萩原聖人': 57.7, '二階堂亜樹': 11.7, '小林剛': -20.7, '高宮まり': -48.7}
# 20191108 1 {'勝又健志': 55.5, '佐々木寿人': 14.1, '瑞原明奈': -23.0, '瀬戸熊直樹': -46.6}
# 20191110 0 {'鈴木たろう': 65.1, '多井隆晴': 23.7, '近藤誠一': -29.5, '岡田紗佳': -59.3}
# 20191110 1 {'内川幸太郎': 80.6, '和久津晶': 14.2, '鈴木たろう': -27.8, '白鳥翔': -67.0}
# 20191111 0 {'佐々木寿人': 64.5, '内川幸太郎': 4.4, '二階堂亜樹': -16.0, '松本吉弘': -52.9}
# 20191111 1 {'佐々木寿人': 51.2, '沢崎誠': 4.0, '松本吉弘': -17.3, '滝沢和典': -37.9}
# 20191112 0 {'村上淳': 60.9, '小林剛': 5.9, '黒沢咲': -21.1, '魚谷侑未': -45.7}
# 20191112 1 {'石橋伸洋': 48.5, '和久津晶': 4.5, '園田賢': -16.0, '萩原聖人': -37.0}
# 20191114 0 {'沢崎誠': 71.8, '魚谷侑未': 19.5, '前原雄大': -33.3, '丸山奏子': -58.0}
# 20191114 1 {'鈴木たろう': 63.9, '近藤誠一': 17.7, '藤崎智': -24.4, '沢崎誠': -57.2}
# 20191115 0 {'二階堂亜樹': 64.7, '朝倉康心': 7.9, '瀬戸熊直樹': -19.7, '日向藍子': -52.9}
# 20191115 1 {'多井隆晴': 57.5, '瀬戸熊直樹': 11.9, '朝倉康心': -17.5, '滝沢和典': -51.9}
# 20191118 0 {'勝又健志': 61.8, '高宮まり': 17.3, '園田賢': -8.3, '黒沢咲': -70.8}
# 20191118 1 {'村上淳': 75.6, '萩原聖人': 17.4, '滝沢和典': -16.6, '前原雄大': -76.4}
# 20191119 0 {'瑞原明奈': 57.0, '岡田紗佳': 15.8, '近藤誠一': -24.0, '松本吉弘': -48.8}
# 20191119 1 {'沢崎誠': 112.1, '小林剛': -16.6, '魚谷侑未': -37.5, '多井隆晴': -58.0}
# 20191121 0 {'白鳥翔': 82.4, '瀬戸熊直樹': 20.4, '佐々木寿人': -24.2, '瑞原明奈': -78.6}
# 20191121 1 {'日向藍子': 57.8, '石橋伸洋': 8.5, '佐々木寿人': -17.2, '黒沢咲': -49.1}
# 20191122 0 {'園田賢': 68.3, '茅森早香': 1.4, '勝又健志': -20.0, '内川幸太郎': -49.7}
# 20191122 1 {'近藤誠一': 51.1, '二階堂亜樹': 6.9, '内川幸太郎': -13.7, '鈴木たろう': -44.3}
# 20191125 0 {'沢崎誠': 58.1, '白鳥翔': 11.9, '丸山奏子': -24.2, '勝又健志': -45.8}
# 20191125 1 {'滝沢和典': 59.3, '松本吉弘': 7.3, '園田賢': -17.9, '沢崎誠': -48.7}
# 20191126 0 {'前原雄大': 95.8, '魚谷侑未': 5.4, '萩原聖人': -36.8, '小林剛': -64.4}
# 20191126 1 {'瀬戸熊直樹': 102.1, '高宮まり': 12.8, '石橋伸洋': -34.9, '和久津晶': -80.0}
# 20191128 0 {'白鳥翔': 49.6, '瀬戸熊直樹': 8.6, '沢崎誠': -17.4, '茅森早香': -40.8}
# 20191128 1 {'日向藍子': 71.2, '魚谷侑未': 7.3, '岡田紗佳': -19.1, '萩原聖人': -59.4}
# 20191129 0 {'佐々木寿人': 60.0, '村上淳': 15.7, '朝倉康心': -11.8, '滝沢和典': -63.9}
# 20191129 1 {'鈴木たろう': 76.6, '佐々木寿人': -1.6, '朝倉康心': -21.8, '二階堂亜樹': -53.2}
# 20191202 0 {'前原雄大': 72.4, '石橋伸洋': 9.8, '魚谷侑未': -26.1, '沢崎誠': -56.1}
# 20191202 1 {'朝倉康心': 60.8, '茅森早香': 9.8, '佐々木寿人': -19.3, '内川幸太郎': -51.3}
# 20191203 0 {'瀬戸熊直樹': 61.3, '勝又健志': 9.6, '多井隆晴': -17.6, '鈴木たろう': -53.3}
# 20191203 1 {'滝沢和典': 88.1, '松本吉弘': -0.7, '萩原聖人': -27.7, '園田賢': -59.7}
# 20191205 0 {'白鳥翔': 57.8, '小林剛': 8.2, '茅森早香': -18.9, '丸山奏子': -47.1}
# 20191205 1 {'朝倉康心': 67.9, '村上淳': 4.4, '近藤誠一': -15.8, '日向藍子': -56.5}
# 20191206 0 {'岡田紗佳': 64.7, '萩原聖人': 17.5, '滝沢和典': -30.6, '高宮まり': -51.6}
# 20191206 1 {'勝又健志': 60.6, '佐々木寿人': 4.3, '瀬戸熊直樹': -20.6, '沢崎誠': -44.3}
# 20191208 0 {'藤崎智': 68.0, '松本吉弘': 18.5, '勝又健志': -26.4, '萩原聖人': -60.1}
# 20191208 1 {'藤崎智': 58.9, '滝沢和典': 15.7, '瀬戸熊直樹': -19.1, '多井隆晴': -55.5}
# 20191209 0 {'石橋伸洋': 64.5, '内川幸太郎': 13.1, '鈴木たろう': -22.9, '魚谷侑未': -54.7}
# 20191209 1 {'内川幸太郎': 52.9, '茅森早香': 5.6, '朝倉康心': -16.3, '園田賢': -42.2}
# 20191210 0 {'沢崎誠': 69.7, '近藤誠一': 15.8, '黒沢咲': -10.6, '園田賢': -74.9}
# 20191210 1 {'茅森早香': 65.4, '村上淳': 15.6, '瀬戸熊直樹': -24.8, '沢崎誠': -56.2}
# 20191212 0 {'白鳥翔': 73.8, '勝又健志': 6.5, '小林剛': -14.5, '佐々木寿人': -65.8}
# 20191212 1 {'藤崎智': 58.9, '白鳥翔': 6.8, '二階堂亜樹': -20.5, '朝倉康心': -45.2}
# 20191213 0 {'多井隆晴': 72.6, '丸山奏子': 7.2, '岡田紗佳': -23.0, '瑞原明奈': -56.8}
# 20191213 1 {'沢崎誠': 77.4, '多井隆晴': 16.4, '鈴木たろう': -31.8, '石橋伸洋': -62.0}
# 20191216 0 {'黒沢咲': 100.6, '近藤誠一': 30.5, '前原雄大': -38.3, '滝沢和典': -92.8}
# 20191216 1 {'近藤誠一': 71.4, '勝又健志': -3.5, '高宮まり': -23.9, '萩原聖人': -44.0}
# 20191217 0 {'小林剛': 56.6, '茅森早香': 10.7, '高宮まり': -21.2, '二階堂亜樹': -46.1}
# 20191217 1 {'朝倉康心': 71.3, '佐々木寿人': 30.5, '勝又健志': -26.2, '和久津晶': -75.6}
# 20191219 0 {'黒沢咲': 51.1, '松本吉弘': 9.9, '内川幸太郎': -20.4, '丸山奏子': -40.6}
# 20191219 1 {'内川幸太郎': 58.1, '村上淳': 10.0, '瀬戸熊直樹': -17.8, '日向藍子': -50.3}
# 20191220 0 {'茅森早香': 54.6, '瑞原明奈': 3.9, '岡田紗佳': -17.0, '勝又健志': -41.5}
# 20191220 1 {'和久津晶': 69.0, '滝沢和典': 10.2, '内川幸太郎': -24.7, '石橋伸洋': -54.5}
# 20190106 0 {'瀬戸熊直樹': 68.4, '松本吉弘': -0.3, '藤崎智': -24.0, '村上淳': -44.1}
# 20190106 1 {'萩原聖人': 63.8, '多井隆晴': 16.1, '鈴木たろう': -20.0, '前原雄大': -59.9}
# 20190107 0 {'和久津晶': 55.3, '丸山奏子': 11.0, '二階堂亜樹': -17.6, '前原雄大': -48.7}
# 20190107 1 {'近藤誠一': 61.0, '高宮まり': 10.0, '勝又健志': -25.3, '園田賢': -45.7}
# 20190109 0 {'沢崎誠': 68.8, '黒沢咲': 7.7, '小林剛': -15.0, '白鳥翔': -61.5}
# 20190109 1 {'日向藍子': 60.1, '朝倉康心': 10.4, '瀬戸熊直樹': -10.2, '沢崎誠': -60.3}
# 20190110 0 {'魚谷侑未': 74.5, '勝又健志': 12.2, '白鳥翔': -31.7, '黒沢咲': -55.0}
# 20190110 1 {'萩原聖人': 59.7, '魚谷侑未': 15.1, '滝沢和典': -19.8, '松本吉弘': -55.0}
# 20190113 0 {'佐々木寿人': 58.5, '瑞原明奈': 16.9, '村上淳': -15.1, '内川幸太郎': -60.3}
# 20190113 1 {'藤崎智': 62.8, '鈴木たろう': 9.2, '沢崎誠': -13.5, '小林剛': -58.5}
# 20190114 0 {'黒沢咲': 90.6, '丸山奏子': 27.3, '岡田紗佳': -46.3, '石橋伸洋': -71.6}
# 20190114 1 {'朝倉康心': 66.4, '内川幸太郎': 10.4, '園田賢': -22.2, '瀬戸熊直樹': -54.6}
# 20190116 0 {'魚谷侑未': 57.0, '多井隆晴': 3.7, '佐々木寿人': -20.1, '勝又健志': -40.6}
# 20190116 1 {'高宮まり': 64.4, '多井隆晴': 18.1, '勝又健志': -22.2, '茅森早香': -60.3}
# 20190117 0 {'茅森早香': 57.6, '小林剛': 11.0, '松本吉弘': -15.1, '滝沢和典': -53.5}
# 20190117 1 {'二階堂亜樹': 54.0, '魚谷侑未': 4.9, '朝倉康心': -15.4, '白鳥翔': -43.5}
# 20190119 0 {'黒沢咲': 67.6, '前原雄大': 25.9, '岡田紗佳': -30.8, '鈴木たろう': -62.7}
# 20190119 1 {'村上淳': 59.7, '沢崎誠': 16.8, '藤崎智': -19.2, '萩原聖人': -57.3}
# 20190120 0 {'沢崎誠': 62.9, '滝沢和典': 20.9, '瀬戸熊直樹': -21.8, '多井隆晴': -62.0}
# 20190120 1 {'内川幸太郎': 62.5, '松本吉弘': 9.7, '勝又健志': -18.4, '萩原聖人': -53.8}
# 20190121 0 {'小林剛': 51.9, '和久津晶': 11.5, '藤崎智': -16.7, '園田賢': -46.7}
# 20190121 1 {'近藤誠一': 60.4, '瑞原明奈': 18.0, '丸山奏子': -24.5, '高宮まり': -53.9}
# 20190123 0 {'朝倉康心': 53.5, '瀬戸熊直樹': 7.9, '近藤誠一': -15.1, '二階堂亜樹': -46.3}
# 20190123 1 {'萩原聖人': 54.2, '滝沢和典': 12.0, '朝倉康心': -22.3, '茅森早香': -43.9}
# 20190124 0 {'鈴木たろう': 59.7, '沢崎誠': 5.7, '日向藍子': -20.2, '藤崎智': -45.2}
# 20190124 1 {'村上淳': 59.9, '白鳥翔': 0.6, '前原雄大': -20.2, '内川幸太郎': -40.3}
# 20190127 0 {'園田賢': 57.4, '前原雄大': 13.4, '和久津晶': -19.3, '黒沢咲': -51.5}
# 20190127 1 {'村上淳': 57.9, '魚谷侑未': 15.7, '萩原聖人': -26.1, '藤崎智': -47.5}
# 20190128 0 {'勝又健志': 50.8, '小林剛': 10.2, '白鳥翔': -12.4, '沢崎誠': -48.6}
# 20190128 1 {'松本吉弘': 65.6, '朝倉康心': 18.6, '勝又健志': -22.3, '岡田紗佳': -61.9}
# 20190130 0 {'近藤誠一': 72.3, '鈴木たろう': 1.6, '瑞原明奈': -20.9, '滝沢和典': -53.0}
# 20190130 1 {'滝沢和典': 50.6, '村上淳': 7.3, '朝倉康心': -18.0, '茅森早香': -39.9}
# 20190131 0 {'佐々木寿人': 69.8, '黒沢咲': 13.8, '沢崎誠': -16.7, '多井隆晴': -66.9}
# 20190131 1 {'白鳥翔': 57.7, '内川幸太郎': 7.9, '瀬戸熊直樹': -15.3, '前原雄大': -50.3}
# 20190203 0 {'魚谷侑未': 59.9, '沢崎誠': 4.4, '石橋伸洋': -19.2, '佐々木寿人': -45.1}
# 20190203 1 {'小林剛': 77.8, '高宮まり': 4.6, '内川幸太郎': -26.2, '和久津晶': -56.2}
# 20190204 0 {'松本吉弘': 73.7, '瀬戸熊直樹': 6.0, '園田賢': -28.2, '勝又健志': -51.5}
# 20190204 1 {'鈴木たろう': 73.2, '松本吉弘': 11.2, '萩原聖人': -18.6, '二階堂亜樹': -65.8}
# 20190206 0 {'佐々木寿人': 63.0, '近藤誠一': 6.5, '鈴木たろう': -22.4, '日向藍子': -47.1}
# 20190206 1 {'佐々木寿人': 61.2, '村上淳': 4.0, '茅森早香': -21.4, '白鳥翔': -43.8}
# 20190207 0 {'岡田紗佳': 75.0, '朝倉康心': 11.1, '滝沢和典': -9.6, '萩原聖人': -76.5}
# 20190207 1 {'黒沢咲': 87.5, '滝沢和典': -4.1, '小林剛': -28.4, '沢崎誠': -55.0}
# 20190210 0 {'多井隆晴': 49.6, '沢崎誠': 5.5, '二階堂亜樹': -15.2, '佐々木寿人': -39.9}
# 20190210 1 {'高宮まり': 54.2, '沢崎誠': 12.5, '多井隆晴': -15.3, '滝沢和典': -51.4}
# 20190211 0 {'村上淳': 66.6, '魚谷侑未': 20.6, '小林剛': -23.5, '黒沢咲': -63.7}
# 20190211 1 {'和久津晶': 54.5, '萩原聖人': 10.8, '石橋伸洋': -21.7, '丸山奏子': -43.6}
# 20190213 0 {'白鳥翔': 60.4, '内川幸太郎': 3.4, '小林剛': -20.0, '瀬戸熊直樹': -43.8}
# 20190213 1 {'黒沢咲': 60.5, '朝倉康心': 6.5, '内川幸太郎': -14.6, '松本吉弘': -52.4}
# 20190214 0 {'前原雄大': 57.7, '鈴木たろう': 2.8, '滝沢和典': -17.5, '茅森早香': -43.0}
# 20190214 1 {'佐々木寿人': 67.4, '園田賢': 23.0, '近藤誠一': -19.2, '勝又健志': -71.2}
# 20190215 0 {'朝倉康心': 59.4, '魚谷侑未': 2.2, '沢崎誠': -30.8, '滝沢和典': -30.8}
# 20190215 1 {'勝又健志': 61.8, '近藤誠一': 9.9, '岡田紗佳': -19.1, '瑞原明奈': -52.6}
# 20190217 0 {'瀬戸熊直樹': 78.2, '多井隆晴': 17.5, '高宮まり': -30.0, '園田賢': -65.7}
# 20190217 1 {'村上淳': 53.3, '黒沢咲': 7.6, '藤崎智': -18.0, '白鳥翔': -42.9}
# 20190218 0 {'村上淳': 66.0, '茅森早香': 13.6, '多井隆晴': -13.0, '沢崎誠': -66.6}
# 20190218 1 {'内川幸太郎': 85.6, '近藤誠一': 11.8, '鈴木たろう': -27.5, '松本吉弘': -69.9}
# 20190220 0 {'藤崎智': 59.3, '朝倉康心': 1.2, '瀬戸熊直樹': -19.6, '二階堂亜樹': -40.9}
# 20190220 1 {'小林剛': 73.6, '前原雄大': 3.6, '黒沢咲': -18.9, '勝又健志': -58.3}
# 20190221 0 {'沢崎誠': 74.3, '萩原聖人': 3.7, '近藤誠一': -28.0, '藤崎智': -50.0}
# 20190221 1 {'魚谷侑未': 61.8, '佐々木寿人': 16.8, '萩原聖人': -16.0, '岡田紗佳': -62.6}
# 20190224 0 {'多井隆晴': 65.1, '滝沢和典': 16.1, '村上淳': -6.8, '朝倉康心': -74.4}
# 20190224 1 {'多井隆晴': 65.7, '勝又健志': 4.9, '園田賢': -23.5, '朝倉康心': -47.1}
# 20190225 0 {'鈴木たろう': 72.2, '沢崎誠': 11.6, '滝沢和典': -23.4, '瀬戸熊直樹': -60.4}
# 20190225 1 {'黒沢咲': 68.3, '勝又健志': 23.5, '村上淳': 0.7, '内川幸太郎': -92.5}
# 20190227 0 {'魚谷侑未': 114.4, '松本吉弘': -5.4, '前原雄大': -39.0, '石橋伸洋': -70.0}
# 20190227 1 {'小林剛': 59.7, '日向藍子': 9.5, '藤崎智': -15.1, '近藤誠一': -54.1}
# 20190228 0 {'高宮まり': 67.6, '沢崎誠': 11.0, '小林剛': -23.7, '鈴木たろう': -54.9}
# 20190228 1 {'内川幸太郎': 71.5, '村上淳': 19.6, '佐々木寿人': -31.4, '朝倉康心': -59.7}
# 20190302 0 {'白鳥翔': 56.4, '茅森早香': -6.2, '瀬戸熊直樹': -6.2, '二階堂亜樹': -44.0}
# 20190302 1 {'白鳥翔': 51.1, '黒沢咲': 8.6, '滝沢和典': -14.2, '茅森早香': -45.5}
# 20190303 0 {'多井隆晴': 66.7, '園田賢': 20.0, '魚谷侑未': -18.4, '朝倉康心': -68.3}
# 20190303 1 {'魚谷侑未': 73.7, '小林剛': 4.3, '多井隆晴': -27.7, '園田賢': -50.3}
# 20190305 0 {'沢崎誠': 73.5, '佐々木寿人': 10.9, '滝沢和典': -31.7, '瀬戸熊直樹': -52.7}
# 20190305 1 {'勝又健志': 82.3, '前原雄大': 6.7, '萩原聖人': -22.0, '沢崎誠': -67.0}
# 20190306 0 {'小林剛': 56.6, '日向藍子': 12.2, '瀬戸熊直樹': -20.0, '内川幸太郎': -48.8}
# 20190306 1 {'日向藍子': 68.4, '内川幸太郎': 1.6, '小林剛': -23.2, '黒沢咲': -46.8}
# 20190309 0 {'高宮まり': 61.2, '勝又健志': 6.4, '村上淳': -19.9, '茅森早香': -47.7}
# 20190309 1 {'和久津晶': 56.9, '勝又健志': 2.4, '佐々木寿人': -18.1, '村上淳': -41.2}
# 20190316 0 {'内川幸太郎': 49.3, '魚谷侑未': 6.9, '白鳥翔': -17.4, '黒沢咲': -38.8}
# 20190316 1 {'沢崎誠': 59.9, '近藤誠一': 6.2, '瀬戸熊直樹': -19.1, '多井隆晴': -47.0}
# 20190317 0 {'瑞原明奈': 64.0, '前原雄大': 12.8, '瀬戸熊直樹': -17.7, '茅森早香': -59.1}
# 20190317 1 {'石橋伸洋': 64.4, '和久津晶': 13.3, '黒沢咲': -26.9, '藤崎智': -50.8}
# 20190319 0 {'佐々木寿人': 67.2, '松本吉弘': 5.2, '岡田紗佳': -19.3, '朝倉康心': -53.1}
# 20190319 1 {'石橋伸洋': 69.4, '松本吉弘': 1.0, '沢崎誠': -24.1, '高宮まり': -46.3}
# 20190320 0 {'日向藍子': 57.1, '魚谷侑未': 6.1, '萩原聖人': -16.9, '佐々木寿人': -46.3}
# 20190320 1 {'前原雄大': 64.5, '日向藍子': 2.7, '黒沢咲': -21.2, '和久津晶': -46.0}
# 20190321 0 {'沢崎誠': 51.9, '白鳥翔': 8.1, '瑞原明奈': -13.8, '瀬戸熊直樹': -46.2}
# 20190321 1 {'萩原聖人': 71.8, '小林剛': 30.6, '内川幸太郎': -25.3, '白鳥翔': -77.1}
# 20190323 0 {'近藤誠一': 78.9, '沢崎誠': 15.0, '瑞原明奈': -36.6, '前原雄大': -57.3}
# 20190323 1 {'内川幸太郎': 62.1, '石橋伸洋': 3.8, '近藤誠一': -21.0, '藤崎智': -44.9}
# 20190324 0 {'黒沢咲': 58.6, '多井隆晴': 15.4, '小林剛': -14.3, '高宮まり': -59.7}
# 20190324 1 {'石橋伸洋': 51.5, '佐々木寿人': 6.8, '多井隆晴': -18.3, '黒沢咲': -40.0}
# 20190326 0 {'岡田紗佳': 52.8, '近藤誠一': 11.0, '瀬戸熊直樹': -13.6, '佐々木寿人': -50.2}
# 20190326 1 {'瀬戸熊直樹': 73.4, '内川幸太郎': 12.4, '魚谷侑未': -19.4, '前原雄大': -66.4}
# 20190327 0 {'魚谷侑未': 55.8, '沢崎誠': 7.1, '松本吉弘': -14.7, '瑞原明奈': -48.2}
# 20190327 1 {'日向藍子': 55.4, '内川幸太郎': 10.2, '朝倉康心': -13.2, '魚谷侑未': -52.4}
# 20190329 0 {'黒沢咲': 54.0, '小林剛': 11.4, '佐々木寿人': -8.9, '内川幸太郎': -56.5}
# 20190329 1 {'沢崎誠': 69.4, '石橋伸洋': 8.8, '佐々木寿人': -22.1, '萩原聖人': -56.1}
# 20190330 0 {'白鳥翔': 58.1, '石橋伸洋': 17.6, '近藤誠一': -7.6, '瀬戸熊直樹': -68.1}
# 20190330 1 {'黒沢咲': 60.0, '魚谷侑未': 3.5, '多井隆晴': -18.8, '小林剛': -44.7}
# 20190331 0 {'高宮まり': 59.9, '松本吉弘': 4.9, '沢崎誠': -21.8, '茅森早香': -43.0}
# 20190331 1 {'藤崎智': 79.2, '内川幸太郎': 17.4, '和久津晶': -9.0, '日向藍子': -87.6}
# 20190615 0 {'小林剛': 82.7, '多井隆晴': 1.0, '茅森早香': -29.3, '沢崎誠': -54.4}
# 20190615 1 {'魚谷侑未': 49.7, '白鳥翔': 7.4, '石橋伸洋': -16.7, '内川幸太郎': -40.4}
# 20190616 0 {'日向藍子': 65.6, '近藤誠一': 16.7, '瑞原明奈': -28.1, '内川幸太郎': -54.2}
# 20190616 1 {'魚谷侑未': 62.9, '朝倉康心': 8.3, '松本吉弘': -18.1, '沢崎誠': -53.1}
# 20190618 0 {'朝倉康心': 94.4, '岡田紗佳': 4.2, '多井隆晴': -36.7, '近藤誠一': -61.9}
# 20190618 1 {'和久津晶': 54.2, '沢崎誠': 3.4, '白鳥翔': -18.5, '小林剛': -39.1}
# 20190619 0 {'瑞原明奈': 77.2, '魚谷侑未': 10.1, '日向藍子': -26.0, '内川幸太郎': -61.3}
# 20190619 1 {'松本吉弘': 59.6, '魚谷侑未': 13.5, '沢崎誠': -15.2, '小林剛': -57.9}
# 20190622 0 {'多井隆晴': 71.8, '石橋伸洋': 6.9, '魚谷侑未': -19.8, '岡田紗佳': -58.9}
# 20190622 1 {'茅森早香': 50.8, '多井隆晴': 8.7, '朝倉康心': -17.3, '内川幸太郎': -42.2}
# 20190623 0 {'石橋伸洋': 74.8, '内川幸太郎': 1.5, '白鳥翔': -18.9, '近藤誠一': -57.4}
# 20190623 1 {'小林剛': 61.2, '魚谷侑未': 9.6, '沢崎誠': -20.9, '多井隆晴': -49.9}
# 2020
# Read template.
# 20201005 0 {'二階堂亜樹': 57.9, '瀬戸熊直樹': 6.9, '高宮まり': -19.0, '内川幸太郎': -45.8}
# 20201005 1 {'岡田紗佳': 60.4, '勝又健志': 20.0, '藤崎智': -17.2, '萩原聖人': -63.2}
# 20201006 0 {'村上淳': 77.7, '多井隆晴': 4.7, '近藤誠一': -29.5, '石橋伸洋': -52.9}
# 20201006 1 {'鈴木たろう': 64.9, '和久津晶': 3.1, '白鳥翔': -22.3, '瑞原明奈': -45.7}
# 20201008 0 {'茅森早香': 72.0, '滝沢和典': 12.4, '園田賢': -13.6, '前原雄大': -70.8}
# 20201008 1 {'佐々木寿人': 50.5, '二階堂亜樹': 9.8, '魚谷侑未': -15.1, '丸山奏子': -45.2}
# 20201009 0 {'黒沢咲': 66.8, '日向藍子': 7.4, '堀慎吾': -23.2, '朝倉康心': -51.0}
# 20201009 1 {'沢崎誠': 86.4, '小林剛': 18.4, '松本吉弘': -31.7, '萩原聖人': -73.1}
# 20201012 0 {'村上淳': 53.7, '茅森早香': 6.9, '藤崎智': -18.6, '白鳥翔': -42.0}
# 20201012 1 {'多井隆晴': 81.4, '鈴木たろう': 33.4, '高宮まり': -33.7, '和久津晶': -81.1}
# 20201013 0 {'堀慎吾': 71.2, '勝又健志': 4.9, '黒沢咲': -23.1, '瑞原明奈': -53.0}
# 20201013 1 {'小林剛': 67.6, '岡田紗佳': 10.6, '瀬戸熊直樹': -17.1, '勝又健志': -61.1}
# 20201015 0 {'瀬戸熊直樹': 80.9, '石橋伸洋': 11.3, '松本吉弘': -23.0, '佐々木寿人': -69.2}
# 20201015 1 {'日向藍子': 57.6, '朝倉康心': 1.9, '前原雄大': -18.8, '瀬戸熊直樹': -40.7}
# 20201016 0 {'近藤誠一': 70.7, '二階堂亜樹': 14.4, '沢崎誠': -24.6, '園田賢': -60.5}
# 20201016 1 {'内川幸太郎': 59.0, '勝又健志': 9.5, '鈴木たろう': -24.1, '茅森早香': -44.4}
# 20201019 0 {'松本吉弘': 71.9, '小林剛': 11.4, '村上淳': -17.2, '滝沢和典': -66.1}
# 20201019 1 {'滝沢和典': 71.1, '園田賢': 3.8, '石橋伸洋': -23.2, '白鳥翔': -51.7}
# 20201020 0 {'前原雄大': 50.3, '茅森早香': 9.2, '黒沢咲': -15.2, '堀慎吾': -44.3}
# 20201020 1 {'佐々木寿人': 78.8, '魚谷侑未': -0.4, '瀬戸熊直樹': -24.2, '内川幸太郎': -54.2}
# 20201022 0 {'近藤誠一': 68.5, '瑞原明奈': 20.6, '二階堂亜樹': -21.3, '高宮まり': -67.8}
# 20201022 1 {'朝倉康心': 61.3, '勝又健志': 11.2, '和久津晶': -22.8, '藤崎智': -49.7}
# 20201023 0 {'丸山奏子': 63.5, '黒沢咲': 8.0, '沢崎誠': -19.8, '多井隆晴': -51.7}
# 20201023 1 {'鈴木たろう': 69.2, '萩原聖人': 4.9, '白鳥翔': -19.7, '岡田紗佳': -54.4}
# 20201026 0 {'佐々木寿人': 61.1, '滝沢和典': 1.3, '瀬戸熊直樹': -18.8, '石橋伸洋': -43.6}
# 20201026 1 {'滝沢和典': 69.9, '石橋伸洋': 20.5, '佐々木寿人': -32.0, '萩原聖人': -58.4}
# 20201027 0 {'村上淳': 79.6, '松本吉弘': 5.8, '堀慎吾': -32.4, '和久津晶': -53.0}
# 20201027 1 {'日向藍子': 60.7, '堀慎吾': 2.1, '和久津晶': -19.5, '園田賢': -43.3}
# 20201029 0 {'瀬戸熊直樹': 57.5, '岡田紗佳': 10.4, '勝又健志': -17.9, '近藤誠一': -50.0}
# 20201029 1 {'二階堂亜樹': 70.3, '魚谷侑未': 17.0, '黒沢咲': -21.6, '沢崎誠': -65.7}
# 20201030 0 {'高宮まり': 55.1, '瑞原明奈': 8.1, '鈴木たろう': -18.5, '白鳥翔': -44.7}
# 20201030 1 {'園田賢': 57.9, '多井隆晴': 11.4, '前原雄大': -18.6, '朝倉康心': -50.7}
# 20201102 0 {'滝沢和典': 59.4, '松本吉弘': 12.6, '石橋伸洋': -25.9, '内川幸太郎': -46.1}
# 20201102 1 {'堀慎吾': 53.9, '滝沢和典': 4.9, '朝倉康心': -15.3, '多井隆晴': -43.5}
# 20201103 0 {'佐々木寿人': 79.1, '丸山奏子': 6.3, '萩原聖人': -26.4, '魚谷侑未': -59.0}
# 20201103 1 {'村上淳': 54.7, '瀬戸熊直樹': 9.1, '近藤誠一': -11.8, '前原雄大': -52.0}
# 20201105 0 {'魚谷侑未': 61.6, '白鳥翔': 15.3, '黒沢咲': -22.1, '瑞原明奈': -54.8}
# 20201105 1 {'小林剛': 77.6, '魚谷侑未': 3.5, '萩原聖人': -20.5, '日向藍子': -60.6}
# 20201106 0 {'二階堂亜樹': 68.2, '園田賢': 7.4, '高宮まり': -23.4, '沢崎誠': -52.2}
# 20201106 1 {'佐々木寿人': 78.6, '勝又健志': 15.8, '鈴木たろう': -22.9, '岡田紗佳': -71.5}
# 20201109 0 {'瀬戸熊直樹': 55.7, '前原雄大': 8.0, '朝倉康心': -21.3, '茅森早香': -42.4}
# 20201109 1 {'藤崎智': 78.9, '黒沢咲': 10.3, '石橋伸洋': -17.4, '近藤誠一': -71.8}
# 20201110 0 {'勝又健志': 71.1, '堀慎吾': 6.5, '村上淳': -22.0, '多井隆晴': -55.6}
# 20201110 1 {'白鳥翔': 62.6, '堀慎吾': 4.6, '鈴木たろう': -21.1, '滝沢和典': -46.1}
# 20201112 0 {'和久津晶': 60.2, '園田賢': 13.1, '岡田紗佳': -25.2, '萩原聖人': -48.1}
# 20201112 1 {'村上淳': 58.3, '沢崎誠': 16.5, '黒沢咲': -25.3, '魚谷侑未': -49.5}
# 20201113 0 {'勝又健志': 78.0, '小林剛': 18.0, '松本吉弘': -25.4, '前原雄大': -70.6}
# 20201113 1 {'瑞原明奈': 60.5, '日向藍子': 14.0, '高宮まり': -23.2, '二階堂亜樹': -51.3}
# 20201116 0 {'松本吉弘': 81.0, '二階堂亜樹': 13.1, '佐々木寿人': -26.7, '近藤誠一': -67.4}
# 20201116 1 {'多井隆晴': 60.9, '藤崎智': 5.3, '魚谷侑未': -21.7, '勝又健志': -44.5}
# 20201117 0 {'石橋伸洋': 62.1, '内川幸太郎': 11.9, '黒沢咲': -13.0, '丸山奏子': -61.0}
# 20201117 1 {'瀬戸熊直樹': 46.2, '瑞原明奈': 5.4, '鈴木たろう': -25.8, '内川幸太郎': -25.8}
# 20201119 0 {'茅森早香': 60.1, '園田賢': 9.0, '白鳥翔': -18.0, '瀬戸熊直樹': -51.1}
# 20201119 1 {'松本吉弘': 70.9, '村上淳': 9.3, '和久津晶': -19.2, '萩原聖人': -61.0}
# 20201120 0 {'佐々木寿人': 63.9, '沢崎誠': 12.2, '小林剛': -10.1, '勝又健志': -66.0}
# 20201120 1 {'勝又健志': 78.0, '佐々木寿人': 14.7, '沢崎誠': -23.8, '朝倉康心': -68.9}
# 20201123 0 {'和久津晶': 58.1, '鈴木たろう': 8.0, '石橋伸洋': -22.5, '岡田紗佳': -43.6}
# 20201123 1 {'堀慎吾': 70.8, '小林剛': 5.2, '鈴木たろう': -24.8, '和久津晶': -51.2}
# 20201124 0 {'黒沢咲': 57.0, '日向藍子': 1.4, '高宮まり': -19.1, '二階堂亜樹': -39.3}
# 20201124 1 {'白鳥翔': 69.0, '瀬戸熊直樹': 7.6, '佐々木寿人': -23.0, '滝沢和典': -53.6}
# 20201126 0 {'近藤誠一': 67.6, '松本吉弘': 8.6, '瑞原明奈': -16.6, '滝沢和典': -59.6}
# 20201126 1 {'多井隆晴': 71.6, '二階堂亜樹': 14.1, '近藤誠一': -28.6, '朝倉康心': -57.1}
# 20201127 0 {'藤崎智': 48.3, '黒沢咲': 4.8, '村上淳': -16.0, '沢崎誠': -37.1}
# 20201127 1 {'前原雄大': 59.8, '萩原聖人': 15.6, '内川幸太郎': -25.3, '園田賢': -50.1}
# 20201130 0 {'滝沢和典': 61.9, '前原雄大': 14.0, '瀬戸熊直樹': -14.3, '近藤誠一': -61.6}
# 20201130 1 {'藤崎智': 58.7, '魚谷侑未': 3.2, '滝沢和典': -17.8, '萩原聖人': -44.1}
# 20201201 0 {'白鳥翔': 84.7, '堀慎吾': 9.2, '瑞原明奈': -25.3, '丸山奏子': -68.6}
# 20201201 1 {'小林剛': 79.3, '松本吉弘': 0.9, '堀慎吾': -19.8, '鈴木たろう': -60.4}
# 20201203 0 {'朝倉康心': 65.5, '日向藍子': 11.9, '黒沢咲': -19.9, '村上淳': -57.5}
# 20201203 1 {'園田賢': 68.0, '石橋伸洋': 4.4, '瀬戸熊直樹': -15.8, '多井隆晴': -56.6}
# 20201204 0 {'滝沢和典': 71.6, '岡田紗佳': 19.5, '魚谷侑未': -27.0, '高宮まり': -64.1}
# 20201204 1 {'佐々木寿人': 92.1, '二階堂亜樹': 6.2, '魚谷侑未': -30.2, '沢崎誠': -68.1}
# 20201207 0 {'沢崎誠': 69.4, '萩原聖人': 9.9, '村上淳': -24.3, '勝又健志': -55.0}
# 20201207 1 {'二階堂亜樹': 68.8, '鈴木たろう': 11.0, '萩原聖人': -19.4, '堀慎吾': -60.4}
# 20201208 0 {'佐々木寿人': 66.5, '白鳥翔': 9.0, '石橋伸洋': -18.8, '和久津晶': -56.7}
# 20201208 1 {'茅森早香': 57.2, '瑞原明奈': 7.6, '日向藍子': -13.6, '藤崎智': -51.2}
# 20201210 0 {'内川幸太郎': 96.7, '村上淳': -0.2, '藤崎智': -37.5, '茅森早香': -59.0}
# 20201210 1 {'前原雄大': 65.1, '内川幸太郎': 3.1, '魚谷侑未': -22.1, '園田賢': -46.1}
# 20201211 0 {'黒沢咲': 60.3, '滝沢和典': 5.5, '小林剛': -18.7, '松本吉弘': -47.1}
# 20201211 1 {'瀬戸熊直樹': 67.9, '朝倉康心': 14.8, '白鳥翔': -27.7, '滝沢和典': -55.0}
# 20201214 0 {'岡田紗佳': 67.9, '瀬戸熊直樹': 16.8, '石橋伸洋': -30.4, '高宮まり': -54.3}
# 20201214 1 {'黒沢咲': 101.3, '小林剛': -4.4, '佐々木寿人': -35.4, '沢崎誠': -61.5}
# 20201215 0 {'勝又健志': 62.3, '白鳥翔': 1.2, '丸山奏子': -19.3, '和久津晶': -44.2}
# 20201215 1 {'茅森早香': 67.1, '勝又健志': 8.2, '日向藍子': -23.2, '鈴木たろう': -52.1}
# 20201217 0 {'和久津晶': 58.1, '二階堂亜樹': 11.2, '多井隆晴': -18.4, '黒沢咲': -50.9}
# 20201217 1 {'松本吉弘': 67.8, '萩原聖人': 22.4, '茅森早香': -30.2, '勝又健志': -60.0}
# 20201218 0 {'堀慎吾': 54.1, '佐々木寿人': 11.7, '瑞原明奈': -21.0, '園田賢': -44.8}
# 20201218 1 {'内川幸太郎': 63.1, '村上淳': 8.1, '高宮まり': -14.1, '朝倉康心': -57.1}
# 20201221 0 {'滝沢和典': 55.4, '堀慎吾': 10.2, '瑞原明奈': -12.4, '園田賢': -53.2}
# 20201221 1 {'鈴木たろう': 50.1, '小林剛': 6.1, '二階堂亜樹': -15.0, '内川幸太郎': -41.2}
# 20201222 0 {'日向藍子': 55.5, '萩原聖人': 13.1, '魚谷侑未': -10.8, '前原雄大': -57.8}
# 20201222 1 {'茅森早香': 74.2, '松本吉弘': 14.6, '藤崎智': -17.9, '瀬戸熊直樹': -70.9}
# 20201224 0 {'高宮まり': 67.6, '石橋伸洋': 12.6, '村上淳': -9.6, '黒沢咲': -70.6}
# 20201224 1 {'萩原聖人': 59.3, '園田賢': 10.5, '小林剛': -16.7, '佐々木寿人': -53.1}
# 20201225 0 {'滝沢和典': 66.9, '多井隆晴': 10.7, '岡田紗佳': -28.4, '近藤誠一': -49.2}
# 20201225 1 {'内川幸太郎': 69.4, '和久津晶': 16.2, '滝沢和典': -11.3, '白鳥翔': -74.3}
# 20200102 0 {'堀慎吾': 112.9, '佐々木寿人': -1.4, '茅森早香': -39.3, '日向藍子': -72.2}
# 20200102 1 {'茅森早香': 61.0, '多井隆晴': 9.3, '前原雄大': -16.2, '沢崎誠': -54.1}
# 20200103 0 {'瀬戸熊直樹': 63.3, '丸山奏子': 17.4, '勝又健志': -22.0, '石橋伸洋': -58.7}
# 20200103 1 {'小林剛': 74.9, '萩原聖人': 13.5, '鈴木たろう': -17.7, '二階堂亜樹': -70.7}
# 20200104 0 {'内川幸太郎': 65.2, '高宮まり': 22.7, '白鳥翔': -19.2, '園田賢': -68.7}
# 20200104 1 {'松本吉弘': 78.5, '藤崎智': 0.9, '村上淳': -20.3, '堀慎吾': -59.1}
# 20200105 0 {'瑞原明奈': 66.7, '勝又健志': 20.2, '和久津晶': -30.8, '瀬戸熊直樹': -56.1}
# 20200105 1 {'黒沢咲': 63.4, '小林剛': 1.6, '二階堂亜樹': -19.0, '茅森早香': -46.0}
# 20200107 0 {'松本吉弘': 75.0, '沢崎誠': 11.9, '朝倉康心': -26.7, '和久津晶': -60.2}
# 20200107 1 {'茅森早香': 68.4, '松本吉弘': 25.7, '沢崎誠': -27.5, '石橋伸洋': -66.6}
# 20200108 0 {'村上淳': 66.2, '黒沢咲': 22.6, '滝沢和典': -18.7, '佐々木寿人': -70.1}
# 20200108 1 {'鈴木たろう': 54.3, '佐々木寿人': 13.9, '滝沢和典': -16.5, '萩原聖人': -51.7}
# 20200111 0 {'白鳥翔': 49.3, '萩原聖人': 5.0, '岡田紗佳': -16.2, '勝又健志': -38.1}
# 20200111 1 {'瀬戸熊直樹': 55.2, '多井隆晴': 6.0, '沢崎誠': -20.4, '勝又健志': -40.8}
# 20200112 0 {'近藤誠一': 73.6, '佐々木寿人': 14.5, '鈴木たろう': -34.0, '瑞原明奈': -54.1}
# 20200112 1 {'茅森早香': 59.6, '藤崎智': 9.1, '園田賢': -23.9, '小林剛': -44.8}
# 20200114 0 {'勝又健志': 96.0, '朝倉康心': 5.1, '村上淳': -35.2, '前原雄大': -65.9}
# 20200114 1 {'園田賢': 58.2, '高宮まり': 6.8, '二階堂亜樹': -13.9, '石橋伸洋': -51.1}
# 20200115 0 {'萩原聖人': 68.6, '日向藍子': 18.2, '魚谷侑未': -29.9, '堀慎吾': -56.9}
# 20200115 1 {'黒沢咲': 55.9, '内川幸太郎': 8.6, '魚谷侑未': -13.8, '松本吉弘': -50.7}
# 20200118 0 {'白鳥翔': 60.6, '前原雄大': 16.3, '沢崎誠': -23.8, '黒沢咲': -53.1}
# 20200118 1 {'佐々木寿人': 63.9, '多井隆晴': 10.9, '内川幸太郎': -15.2, '瀬戸熊直樹': -59.6}
# 20200119 0 {'二階堂亜樹': 51.2, '魚谷侑未': 3.6, '小林剛': -16.6, '鈴木たろう': -38.2}
# 20200119 1 {'園田賢': 65.3, '朝倉康心': 9.9, '近藤誠一': -19.2, '二階堂亜樹': -56.0}
# 20200121 0 {'日向藍子': 59.3, '滝沢和典': 9.4, '黒沢咲': -14.7, '村上淳': -54.0}
# 20200121 1 {'多井隆晴': 64.2, '園田賢': 6.2, '萩原聖人': -18.3, '滝沢和典': -52.1}
# 20200122 0 {'堀慎吾': 54.5, '茅森早香': 3.7, '小林剛': -17.9, '高宮まり': -40.3}
# 20200122 1 {'魚谷侑未': 59.9, '藤崎智': 5.5, '朝倉康心': -17.4, '岡田紗佳': -48.0}
# 20200125 0 {'堀慎吾': 53.1, '藤崎智': 5.9, '二階堂亜樹': -14.7, '松本吉弘': -44.3}
# 20200125 1 {'白鳥翔': 52.7, '勝又健志': 3.5, '佐々木寿人': -17.0, '堀慎吾': -39.2}
# 20200126 0 {'和久津晶': 78.8, '瀬戸熊直樹': 3.3, '瑞原明奈': -26.6, '村上淳': -55.5}
# 20200126 1 {'鈴木たろう': 59.7, '小林剛': 14.4, '茅森早香': -13.7, '萩原聖人': -60.4}
# 20200128 0 {'内川幸太郎': 54.3, '小林剛': 14.0, '二階堂亜樹': -23.2, '近藤誠一': -45.1}
# 20200128 1 {'内川幸太郎': 71.9, '朝倉康心': 12.3, '魚谷侑未': -28.5, '勝又健志': -55.7}
# 20200129 0 {'前原雄大': 76.1, '瀬戸熊直樹': 18.6, '日向藍子': -27.6, '鈴木たろう': -67.1}
# 20200129 1 {'黒沢咲': 59.2, '多井隆晴': 6.0, '高宮まり': -22.3, '園田賢': -42.9}
# 20200201 0 {'小林剛': 59.4, '前原雄大': 4.5, '日向藍子': -17.9, '沢崎誠': -46.0}
# 20200201 1 {'多井隆晴': 78.2, '石橋伸洋': 14.2, '堀慎吾': -12.5, '佐々木寿人': -79.9}
# 20200202 0 {'丸山奏子': 64.4, '萩原聖人': 12.9, '滝沢和典': -24.6, '茅森早香': -52.7}
# 20200202 1 {'魚谷侑未': 56.1, '黒沢咲': 4.3, '村上淳': -17.4, '二階堂亜樹': -43.0}
# 20200204 0 {'園田賢': 63.1, '堀慎吾': 15.7, '和久津晶': -4.9, '藤崎智': -73.9}
# 20200204 1 {'近藤誠一': 50.8, '鈴木たろう': 6.4, '内川幸太郎': -15.6, '高宮まり': -41.6}
# 20200205 0 {'瑞原明奈': 60.1, '瀬戸熊直樹': 16.8, '松本吉弘': -22.7, '滝沢和典': -54.2}
# 20200205 1 {'黒沢咲': 69.5, '小林剛': 4.7, '勝又健志': -17.9, '多井隆晴': -56.3}
# 20200208 0 {'岡田紗佳': 74.0, '魚谷侑未': 4.9, '小林剛': -16.2, '瀬戸熊直樹': -62.7}
# 20200208 1 {'内川幸太郎': 60.2, '茅森早香': 1.6, '朝倉康心': -18.9, '萩原聖人': -42.9}
# 20200209 0 {'高宮まり': 56.3, '白鳥翔': 9.3, '二階堂亜樹': -12.5, '丸山奏子': -53.1}
# 20200209 1 {'村上淳': 60.3, '日向藍子': 11.7, '滝沢和典': -9.3, '前原雄大': -62.7}
# 20200211 0 {'瀬戸熊直樹': 55.0, '多井隆晴': 7.7, '魚谷侑未': -17.7, '園田賢': -45.0}
# 20200211 1 {'鈴木たろう': 64.0, '松本吉弘': 13.0, '魚谷侑未': -15.0, '黒沢咲': -62.0}
# 20200212 0 {'二階堂亜樹': 51.9, '佐々木寿人': 9.9, '沢崎誠': -15.4, '瑞原明奈': -46.4}
# 20200212 1 {'堀慎吾': 62.3, '小林剛': 16.0, '前原雄大': -25.1, '勝又健志': -53.2}
# 20200215 0 {'萩原聖人': 66.8, '村上淳': 10.5, '二階堂亜樹': -27.1, '高宮まり': -50.2}
# 20200215 1 {'瀬戸熊直樹': 50.4, '勝又健志': 9.0, '藤崎智': -17.4, '鈴木たろう': -42.0}
# 20200216 0 {'石橋伸洋': 63.1, '沢崎誠': 3.4, '茅森早香': -22.0, '日向藍子': -44.5}
# 20200216 1 {'松本吉弘': 66.4, '魚谷侑未': 12.3, '小林剛': -19.7, '内川幸太郎': -59.0}
# 20200218 0 {'佐々木寿人': 55.2, '内川幸太郎': 13.9, '丸山奏子': -8.3, '白鳥翔': -60.8}
# 20200218 1 {'佐々木寿人': 114.0, '多井隆晴': -2.7, '堀慎吾': -43.6, '園田賢': -67.7}
# 20200219 0 {'滝沢和典': 69.7, '近藤誠一': 5.1, '朝倉康心': -26.6, '萩原聖人': -48.2}
# 20200219 1 {'魚谷侑未': 57.0, '小林剛': 13.6, '滝沢和典': -17.1, '黒沢咲': -53.5}
# 20200222 0 {'石橋伸洋': 67.2, '岡田紗佳': 14.8, '瀬戸熊直樹': -26.9, '鈴木たろう': -55.1}
# 20200222 1 {'堀慎吾': 64.1, '小林剛': 5.2, '村上淳': -18.6, '萩原聖人': -50.7}
# 20200223 0 {'佐々木寿人': 56.1, '松本吉弘': 10.4, '勝又健志': -15.4, '和久津晶': -51.1}
# 20200223 1 {'近藤誠一': 54.8, '二階堂亜樹': 7.5, '松本吉弘': -19.4, '藤崎智': -42.9}
# 20200225 0 {'園田賢': 73.0, '堀慎吾': 6.2, '茅森早香': -21.0, '二階堂亜樹': -58.2}
# 20200225 1 {'内川幸太郎': 55.1, '近藤誠一': 11.7, '滝沢和典': -16.4, '村上淳': -50.4}
# 20200226 0 {'瑞原明奈': 55.9, '黒沢咲': 10.8, '多井隆晴': -21.5, '佐々木寿人': -45.2}
# 20200226 1 {'小林剛': 59.1, '高宮まり': 12.3, '松本吉弘': -14.9, '黒沢咲': -56.5}
# 20200301 0 {'勝又健志': 58.6, '松本吉弘': 6.2, '村上淳': -15.7, '石橋伸洋': -49.1}
# 20200301 1 {'園田賢': 65.4, '松本吉弘': 0.4, '小林剛': -20.8, '勝又健志': -45.0}
# 20200302 0 {'沢崎誠': 59.6, '前原雄大': 12.6, '瀬戸熊直樹': -11.5, '和久津晶': -60.7}
# 20200302 1 {'岡田紗佳': 63.3, '高宮まり': 6.3, '黒沢咲': -18.0, '魚谷侑未': -51.6}
# 20200304 0 {'鈴木たろう': 82.9, '近藤誠一': -0.6, '佐々木寿人': -28.5, '朝倉康心': -53.8}
# 20200304 1 {'近藤誠一': 50.8, '園田賢': 10.5, '小林剛': -14.8, '前原雄大': -46.5}
# 20200305 0 {'多井隆晴': 87.8, '堀慎吾': 5.1, '滝沢和典': -26.5, '萩原聖人': -66.4}
# 20200305 1 {'内川幸太郎': 65.4, '滝沢和典': 11.1, '瀬戸熊直樹': -18.5, '松本吉弘': -58.0}
# 20200308 0 {'内川幸太郎': 59.7, '藤崎智': 9.3, '瀬戸熊直樹': -22.1, '瑞原明奈': -46.9}
# 20200308 1 {'黒沢咲': 60.1, '堀慎吾': 10.5, '小林剛': -10.2, '藤崎智': -60.4}
# 20200309 0 {'多井隆晴': 64.2, '鈴木たろう': 6.4, '滝沢和典': -23.6, '近藤誠一': -47.0}
# 20200309 1 {'村上淳': 58.4, '多井隆晴': 13.7, '勝又健志': -12.0, '茅森早香': -60.1}
# 20200311 0 {'佐々木寿人': 51.1, '園田賢': 7.8, '勝又健志': -15.0, '瀬戸熊直樹': -43.9}
# 20200311 1 {'黒沢咲': 58.5, '園田賢': 11.9, '二階堂亜樹': -16.9, '前原雄大': -53.5}
# 20200312 0 {'白鳥翔': 76.4, '石橋伸洋': 14.9, '内川幸太郎': -25.2, '魚谷侑未': -66.1}
# 20200312 1 {'内川幸太郎': 64.6, '小林剛': 1.9, '近藤誠一': -18.5, '多井隆晴': -48.0}
# 20200412 0 {'二階堂亜樹': 59.8, '日向藍子': 7.8, '岡田紗佳': -19.6, '佐々木寿人': -48.0}
# 20200412 1 {'堀慎吾': 48.8, '藤崎智': 5.9, '白鳥翔': -14.7, '滝沢和典': -40.0}
# 20200413 0 {'丸山奏子': 72.0, '松本吉弘': -0.9, '前原雄大': -21.5, '瀬戸熊直樹': -49.6}
# 20200413 1 {'高宮まり': 98.0, '萩原聖人': -2.4, '多井隆晴': -34.2, '村上淳': -61.4}
# 20200415 0 {'黒沢咲': 51.8, '園田賢': 8.5, '勝又健志': -17.6, '沢崎誠': -42.7}
# 20200415 1 {'黒沢咲': 58.5, '鈴木たろう': 15.3, '内川幸太郎': -13.2, '勝又健志': -60.6}
# 20200416 0 {'堀慎吾': 97.0, '高宮まり': -0.5, '松本吉弘': -23.6, '丸山奏子': -72.9}
# 20200416 1 {'村上淳': 58.6, '日向藍子': 7.3, '佐々木寿人': -12.9, '内川幸太郎': -53.0}
# 20200419 0 {'滝沢和典': 65.2, '岡田紗佳': 19.1, '佐々木寿人': -12.5, '萩原聖人': -71.8}
# 20200419 1 {'瀬戸熊直樹': 58.6, '沢崎誠': 5.5, '滝沢和典': -15.2, '藤崎智': -48.9}
